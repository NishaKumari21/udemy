# %%
from sklearn.datasets import load_iris
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# %%
df= load_iris()
x= iris.data
y=iris.target

# %%
# Compute linkage matrix
linked = linkage(x, method='ward')

# %% [markdown]
#  x– Dataset<br>
# Jaise agar tum Iris dataset use kar rahi ho, toh X me har phool ke features (jaise petal length, width) store hote hain.
# <br><br>
# 🔹 linkage() – Function
# Yeh scipy.cluster.hierarchy ka ek function hai.
# Iska kaam hai ki dendrogram banane ke liye ek matrix (linkage matrix) create karna.
# Yeh matrix batata hai ki kaunse clusters ek dusre ke saath merge hue hain, kis distance pe hue hain, etc.
# <br><br>
# 🔹 method='ward' – Linkage Criterion
# ward method ka kaam hai ki:
# Jab clusters ban rahe hoon, toh jitni ho sake kam internal difference (variance) ho unmein.
# Yeh method compact aur circular shape wale clusters ke liye best hai.
# Yeh Euclidean distance pe kaam karta hai.

# %%
plt.figure(figsize=(10, 5))
dendrogram(linked,
           orientation='top',
           labels=iris.target)
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
model = AgglomerativeClustering(n_clusters=3, linkage='ward')
labels = model.fit_predict(x)

# %%
plt.scatter(x[:, 0], x[:, 1], c=labels, cmap='rainbow')
plt.title("Agglomerative Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
# Divisive Clustering (Not in sklearn — but can simulate using SciPy or custom logic)
# Divisive clustering isn’t natively available in scikit-learn, but here's how you'd think of it:

# Idea:

# Start with all data points as one cluster.

# Use KMeans or other techniques to recursively split.
